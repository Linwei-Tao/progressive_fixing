# %%
import json
run_name = "resnet50_cifar10_cross_entropy_WD=0.0001_220118193418"
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_train_loss.json",)
train_loss_baseline = json.load(f)
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_test_loss.json",)
test_loss_baseline = json.load(f)
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_val_loss.json",)
val_loss_baseline = json.load(f)
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_val_error.json",)
val_error_baseline = json.load(f)


import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["font.family"]="SimHei"
train_loss_arr_baseline=[train_loss_baseline[f'{i}'] for i in range(350)]
val_loss_arr_baseline=[val_loss_baseline[f'{i}'] for i in range(350)]
test_loss_arr_baseline=[test_loss_baseline[f'{i}'] for i in range(350)]
x=np.arange(350)
fig=plt.figure(num=1,figsize=(6,4))

ax=fig.add_subplot(111)
ax.plot(x,train_loss_arr_baseline,"r-",label="Train")
ax.plot(x,val_loss_arr_baseline,"c-",label="Val")
ax.plot(x,test_loss_arr_baseline,"b-",label="Test")


ax.set_ylabel("Loss")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色
ax.set_xlabel("Epoch")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色

ax.set_title(run_name)

ax.spines["top"].set_visible(False)#上轴不显示
ax.spines["right"].set_visible(False)


ax.legend()

plt.show()

# %%
import json
run_name = "resnet50_cifar10_cross_entropy_PF_1=100_PF_2=200_WD=0.0001_220118203926"
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_train_loss.json",)
train_loss_PF_100_200 = json.load(f)
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_test_loss.json",)
test_loss_PF_100_200 = json.load(f)
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_val_loss.json",)
val_loss_PF_100_200 = json.load(f)
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_val_error.json",)
val_error_PF_100_200 = json.load(f)


import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["font.family"]="SimHei"
train_loss_arr_PF_100_200=[train_loss_PF_100_200[f'{i}'] for i in range(350)]
val_loss_arr_PF_100_200=[val_loss_PF_100_200[f'{i}'] for i in range(350)]
test_loss_arr_PF_100_200=[test_loss_PF_100_200[f'{i}'] for i in range(350)]
x=np.arange(350)
fig=plt.figure(num=1,figsize=(12,4))

ax=fig.add_subplot(121)
ax.plot(x,train_loss_arr_PF_100_200,"r-",label="Train")
ax.plot(x,val_loss_arr_PF_100_200,"c-",label="Val")
ax.plot(x,test_loss_arr_PF_100_200,"b-",label="Test")


ax.set_ylabel("Loss")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色
ax.set_xlabel("Epoch")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色

ax.set_title(run_name)

ax.spines["top"].set_visible(False)#上轴不显示
ax.spines["right"].set_visible(False)


ax.legend()

ax2=fig.add_subplot(122)
ax2.plot(x,val_loss_arr_baseline,"r-",label="Baseline")
ax2.plot(x,val_loss_arr_PF_100_200,"c-",label="Ours")


ax2.set_ylabel("Loss")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色
ax2.set_xlabel("Epoch")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色

ax2.set_title("Val loss comparison with baseline")

ax2.spines["top"].set_visible(False)#上轴不显示
ax2.spines["right"].set_visible(False)


ax2.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3356709/70542850.py in <module>
#      38
#      39 ax2=fig.add_subplot(122)
# ---> 40 ax2.plot(x,val_loss_arr_baseline,"r-",label="Baseline")
#      41 ax2.plot(x,val_loss_arr_PF_100_200,"c-",label="Ours")
#      42
#
# NameError: name 'val_loss_arr_baseline' is not defined
# findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans.

# %%
import json
run_name = "resnet50_cifar10_cross_entropy_PF_1=150_PF_2=250_WD=0.0001_220118231039"
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_train_loss.json",)
train_loss_PF_150_250 = json.load(f)
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_test_loss.json",)
test_loss_PF_150_250 = json.load(f)
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_val_loss.json",)
val_loss_PF_150_250 = json.load(f)
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_val_error.json",)
val_error_PF_150_250 = json.load(f)


import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["font.family"]="SimHei"
train_loss_arr_PF_150_250=[train_loss_PF_150_250[f'{i}'] for i in range(350)]
val_loss_arr_PF_150_250=[val_loss_PF_150_250[f'{i}'] for i in range(350)]
test_loss_arr_PF_150_250=[test_loss_PF_150_250[f'{i}'] for i in range(350)]
x=np.arange(350)
fig=plt.figure(num=1,figsize=(12,4))

ax=fig.add_subplot(121)
ax.plot(x,train_loss_arr_PF_150_250,"r-",label="Train")
ax.plot(x,val_loss_arr_PF_150_250,"c-",label="Val")
ax.plot(x,test_loss_arr_PF_150_250,"b-",label="Test")


ax.set_ylabel("Loss")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色
ax.set_xlabel("Epoch")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色

ax.set_title(run_name)

ax.spines["top"].set_visible(False)#上轴不显示
ax.spines["right"].set_visible(False)


ax.legend()

ax2=fig.add_subplot(122)
ax2.plot(x,val_loss_arr_baseline,"r-",label="Baseline")
ax2.plot(x,val_loss_arr_PF_150_250,"c-",label="Ours")


ax2.set_ylabel("Loss")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色
ax2.set_xlabel("Epoch")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色

ax2.set_title("Val loss comparison with baseline")

ax2.spines["top"].set_visible(False)#上轴不显示
ax2.spines["right"].set_visible(False)


ax2.legend()

plt.show()

# %%
import json
run_name = "resnet50_cifar10_cross_entropy_PF_1=200_PF_2=300_WD=0.0001_220118231132"
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_train_loss.json",)
train_loss_PF_200_300 = json.load(f)
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_test_loss.json",)
test_loss_PF_200_300 = json.load(f)
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_val_loss.json",)
val_loss_PF_200_300 = json.load(f)
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_val_error.json",)
val_error_PF_200_300 = json.load(f)

import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["font.family"]="SimHei"
train_loss_arr_PF_200_300=[train_loss_PF_200_300[f'{i}'] for i in range(350)]
val_loss_arr_PF_200_300=[val_loss_PF_200_300[f'{i}'] for i in range(350)]
test_loss_arr_PF_200_300=[test_loss_PF_200_300[f'{i}'] for i in range(350)]
x=np.arange(350)
fig=plt.figure(num=1,figsize=(12,4))

ax=fig.add_subplot(121)
ax.plot(x,train_loss_arr_PF_200_300,"r-",label="Train")
ax.plot(x,val_loss_arr_PF_200_300,"c-",label="Val")
ax.plot(x,test_loss_arr_PF_200_300,"b-",label="Test")


ax.set_ylabel("Loss")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色
ax.set_xlabel("Epoch")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色

ax.set_title(run_name)

ax.spines["top"].set_visible(False)#上轴不显示
ax.spines["right"].set_visible(False)


ax.legend()

ax2=fig.add_subplot(122)
ax2.plot(x,val_loss_arr_baseline,"r-",label="Baseline")
ax2.plot(x,val_loss_arr_PF_200_300,"c-",label="Ours")


ax2.set_ylabel("Loss")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色
ax2.set_xlabel("Epoch")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色

ax2.set_title("Val loss comparison with baseline")

ax2.spines["top"].set_visible(False)#上轴不显示
ax2.spines["right"].set_visible(False)


ax2.legend()

plt.show()

# %%
import json
run_name = "resnet50_cifar10_cross_entropy_PF=40_WD=0.0001_220118181547"
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_train_loss.json",)
train_loss_PF_200_300 = json.load(f)
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_test_loss.json",)
test_loss_PF_200_300 = json.load(f)
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_val_loss.json",)
val_loss_PF_200_300 = json.load(f)
f = open(f"/home/dylan/Desktop/progressive_fixing/run/{run_name}/cross_entropy_val_error.json",)
val_error_PF_200_300 = json.load(f)

import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["font.family"]="SimHei"
train_loss_arr_PF_200_300=[train_loss_PF_200_300[f'{i}'] for i in range(350)]
val_loss_arr_PF_200_300=[val_loss_PF_200_300[f'{i}'] for i in range(350)]
test_loss_arr_PF_200_300=[test_loss_PF_200_300[f'{i}'] for i in range(350)]
x=np.arange(350)
fig=plt.figure(num=1,figsize=(12,4))

ax=fig.add_subplot(121)
ax.plot(x,train_loss_arr_PF_200_300,"r-",label="Train")
ax.plot(x,val_loss_arr_PF_200_300,"c-",label="Val")
ax.plot(x,test_loss_arr_PF_200_300,"b-",label="Test")


ax.set_ylabel("Loss")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色
ax.set_xlabel("Epoch")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色

ax.set_title(run_name)

ax.spines["top"].set_visible(False)#上轴不显示
ax.spines["right"].set_visible(False)


ax.legend()

ax2=fig.add_subplot(122)
ax2.plot(x,val_loss_arr_baseline,"r-",label="Baseline")
ax2.plot(x,val_loss_arr_PF_200_300,"c-",label="Ours")


ax2.set_ylabel("Loss")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色
ax2.set_xlabel("Epoch")#添加y轴标签，设置字体大小为16，这里也可以设字体样式与颜色

ax2.set_title("Val loss comparison with baseline")

ax2.spines["top"].set_visible(False)#上轴不显示
ax2.spines["right"].set_visible(False)


ax2.legend()

plt.show()
